# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load("data.npz")
data1 = np.load("data1.npz")
with open("movert_1d_s02_prm5_classical_tmax72000_log.csv") as file_name:
    datapy = np.loadtxt(file_name, delimiter=",")

# %%
plt.figure()
# plt.semilogx(data["T"], data["S"][:,2])
plt.semilogx(datapy[:, 0]/10/13.4, datapy[:, 3])
plt.semilogx(data1["T"], data1["S"][:,2])
